# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline
from soccerplots.radar_chart import Radar

# %%
SpLag_df = pd.read_csv('Sporting Lagos.csv')
AbWar_df = pd.read_csv('ABIA WARRIORS.csv')
EnuRan_df = pd.read_csv('ENUGU RANGERS.csv')
HrtFc_df = pd.read_csv('HEARTLAND.csv')
AkwUtd_df = pd.read_csv('AKWA UNITED.csv')
GoUtd_df = pd.read_csv('GOMBE UNITED.csv')
KwaUtd_df = pd.read_csv('KWARA UNITED.csv')
BaUtd_df = pd.read_csv('BAYELSA UNITED.csv')
KPil_df = pd.read_csv('KANO PILLARS.csv')
NiTor_df = pd.read_csv('NIGER TORNADOES.csv')
DoUtd_df = pd.read_csv('DOMA UNITED.csv')
ReSt_df = pd.read_csv('REMO STARS.csv')
RiUtd_df = pd.read_csv('RIVERS UNITED.csv')
BdIns_df = pd.read_csv('BENDEL INSURANCE.csv')
Enyba_df = pd.read_csv('ENYIMBA.csv')
LbSt_df = pd.read_csv('LOBI STARS.csv')
PlatUtd_df = pd.read_csv('PLATEAU UNITED.csv')
KatUtd_df = pd.read_csv('KATSINA UNITED.csv')
ShooSt_df = pd.read_csv('SHOOTING STARS.csv')
SunSt_df = pd.read_csv('SUNSHINE STARS.csv')
style.use('ggplot')

# %%
SpLag_df
matchwk = SpLag_df.index + 1
SpLag_df['GAMEWEEK'] = matchwk
SpLag_df
# Out:
#    MATCH DATE         OPPONENT  POSSESSION  TSH  SOT  SOFT  TSHC  TSCOT  \
# 0  10-02-2023     GOMBE UNITED          52   13    7     6    11      5
# 1  10-08-2023      AKWA UNITED          50    6    3     3    16      5
# 2  10-15-2023      DOMA UNITED          60   17    5    12     9      5
# 3  10-22-2023       REMO STARS          50   12    3     9    11      7
# 4  10-29-2023  NIGER TORNADOES          58    8    4     4    10      1
# 5   11-1-2023     KWARA UNITED          50   12    5     7    11      4
# 6  11-06-2023     KANO PILLARS          48   13    7     6    15      5
# 7  11-12-2023       LOBI STARS          54    8    3     5    12      3
# 8  11-19-2023        HEARTLAND          50   17    5    12     7      3
# 9  11-25-2023   SUNSHINE STARS          50   12    5     7    11      4
#
#    TSCOFT  GS  GC    XG   XGA    XG/SHT   XGA/SHT  GAMEWEEK
# 0       6   2   0  0.72  1.69  0.055385  0.153636         1
# ...

# %%
style.use('ggplot')
 
#plot random no
plt.plot(SpLag_df['GAMEWEEK'],SpLag_df['XG'],'g',label='XG', linewidth=2)
plt.plot(SpLag_df['GAMEWEEK'], SpLag_df['XGA'],'r', label='XGA', linewidth=1.5)



 

#x axis
plt.xlabel('GAMEWEEK')
#y axis
plt.ylabel('XG')
#title
plt.legend()
plt.title('SPORTING LAGOS')
plt.savefig('SPORTING LAGOS')
plt.show()

# %%
AbWar_df
matchwk = AbWar_df.index + 1
AbWar_df['GAMEWEEK'] = matchwk
AbWar_df
# Out:
#    MATCH DATE         OPPONENT  POSSESSION   TSH  SOT  SOFT  TSHC  TSCOT  \
# 0  09-30-2023  NIGER TORNADOES          50   NaN  NaN     0   NaN    NaN
# 1  10-08-2023     KWARA UNITED          50   NaN  NaN     0   NaN    NaN
# 2  10-15-2023     KANO PILLARS          50   NaN  NaN     0   NaN    NaN
# 3  10-22-2023       LOBI STARS          50   NaN  NaN     0   NaN    NaN
# 4  10-29-2023        HEARTLAND          51  11.0  2.0     9   4.0    0.0
# 5  11-01-2023   SUNSHINE STARS          50   NaN  NaN     0   NaN    NaN
# 6  11-05-2023   KATSINA UNITED          50   NaN  NaN     0   NaN    NaN
# 7  11-12-2023   PLATEAU UNITED          50   NaN  NaN     0   NaN    NaN
# 8  11-19-2023    RIVERS UNITED          50   5.0  2.0     3  11.0    5.0
# 9  11-26-2023    ENUGU RANGERS          50   NaN  NaN     0   NaN    NaN
#
#    TSCOFT  GS  GC    XG   XGA  GAMEWEEK
# 0       0   1   0  1.61  0.90         1
# 1       0   0   1  1.25  1.12         2
# 2       0   1   0  1.29  1.02         3
# ...

# %%
#plot random no
plt.plot(AbWar_df['GAMEWEEK'],AbWar_df['XG'],'g',label='XG', linewidth=2)
plt.plot(AbWar_df['GAMEWEEK'], AbWar_df['XGA'],'r', label='XGA', linewidth=1.5)

 

#x axis
plt.xlabel('GAMEWEEK')
#y axis
plt.ylabel('XG')
#title
plt.legend()
plt.title('ABIA WARRIORS')
plt.show()
plt.savefig('ABIA WARRIORS')

# %%
EnuRan_df
matchwk = EnuRan_df.index + 1
EnuRan_df['GAMEWEEK'] = matchwk

# %%
#plot random no
plt.plot(EnuRan_df['GAMEWEEK'],EnuRan_df['XG'],'g',label='XG', linewidth=2)
plt.plot(EnuRan_df['GAMEWEEK'], EnuRan_df['XGA'],'r', label='XGA', linewidth=1.5)
#plt.fill(SpLag_df['GAMEWEEK'],EnuRan_df['XGA'], 'teal', alpha=0.5)
#plt.fill(SpLag_df['GAMEWEEK'],EnuRan_df['XG'], 'teal', alpha=0.5)
 

#x axis
plt.xlabel('GAMEWEEK')
#y axis
plt.ylabel('XG')
#title
plt.legend()
plt.title('ENUGU RANGERS')
plt.savefig('ENUGU RANGERS')

# %%
HrtFc_df
matchwk = HrtFc_df.index + 1
HrtFc_df['GAMEWEEK'] = matchwk

# %%
#plot random no
plt.plot(HrtFc_df['GAMEWEEK'],HrtFc_df['XG'],'g',label='XG', linewidth=2)
plt.plot(HrtFc_df['GAMEWEEK'], HrtFc_df['XGA'],'r', label='XGA', linewidth=1.5)

 

#x axis
plt.xlabel('GAMEWEEK')
#y axis
plt.ylabel('XG')
#title
plt.legend()
plt.title('HEARTLAND FC')
plt.savefig('HEARTLAND FC')

# %%
AkwUtd_df
matchwk = AkwUtd_df.index + 1
AkwUtd_df['GAMEWEEK'] = matchwk

# %%
#plot random no
plt.plot(AkwUtd_df['GAMEWEEK'],AkwUtd_df['XG'],'g',label='XG', linewidth=2)
plt.plot(AkwUtd_df['GAMEWEEK'], AkwUtd_df['XGA'],'r', label='XGA', linewidth=1.5)

 

#x axis
plt.xlabel('GAMEWEEK')
#y axis
plt.ylabel('XG')
#title
plt.legend()
plt.title('AKWA UNITED')
plt.savefig('AKWA UNITED')

# %%
GoUtd_df
matchwk = GoUtd_df.index + 1
GoUtd_df['GAMEWEEK'] = matchwk

# %%
#plot random no
plt.plot(GoUtd_df['GAMEWEEK'],GoUtd_df['XG'],'g',label='XG', linewidth=2)
plt.plot(GoUtd_df['GAMEWEEK'], GoUtd_df['XGA'],'r', label='XGA', linewidth=1.5)

 

#x axis
plt.xlabel('GAMEWEEK')
#y axis
plt.ylabel('XG')
#title
plt.legend()
plt.title('GOMBE UNITED')
plt.savefig('GOMBE UNITED')

# %%
KwaUtd_df
matchwk = KwaUtd_df.index + 1
KwaUtd_df['GAMEWEEK'] = matchwk

# %%
#plot random no
plt.plot(KwaUtd_df['GAMEWEEK'],KwaUtd_df['XG'],'g',label='XG', linewidth=2)
plt.plot(KwaUtd_df['GAMEWEEK'], KwaUtd_df['XGA'],'r', label='XGA', linewidth=1.5)

 

#x axis
plt.xlabel('GAMEWEEK')
#y axis
plt.ylabel('XG')
#title
plt.legend()
plt.title('KWARA UNITED')
plt.savefig('KWARA UNITED')

# %%
BaUtd_df
matchwk = BaUtd_df.index + 1
BaUtd_df['GAMEWEEK'] = matchwk

# %%
#plot random no
plt.plot(SpLag_df['GAMEWEEK'],BaUtd_df['XG'],'g',label='XG', linewidth=2)
plt.plot(SpLag_df['GAMEWEEK'], BaUtd_df['XGA'],'r', label='XGA', linewidth=1.5)

 

#x axis
plt.xlabel('GAMEWEEK')
#y axis
plt.ylabel('XG')
#title
plt.legend()
plt.title('BAYELSA UNITED')
plt.savefig('BAYELSA UNITED')

# %%
KPil_df
matchwk = KPil_df.index + 1
KPil_df['GAMEWEEK'] = matchwk

# %%
#plot random no
plt.plot(SpLag_df['GAMEWEEK'],KPil_df['XG'],'g',label='XG', linewidth=2)
plt.plot(SpLag_df['GAMEWEEK'], KPil_df['XGA'],'r', label='XGA', linewidth=1.5)

 

#x axis
plt.xlabel('GAMEWEEK')
#y axis
plt.ylabel('XG')
#title
plt.legend()
plt.title('KANO PILLARS')
plt.savefig('KANO PILLARS')

# %%
NiTor_df
matchwk = NiTor_df.index + 1
NiTor_df['GAMEWEEK'] = matchwk

# %%
#plot random no
plt.plot(SpLag_df['GAMEWEEK'],NiTor_df['XG'],'g',label='XG', linewidth=2)
plt.plot(SpLag_df['GAMEWEEK'], NiTor_df['XGA'],'r', label='XGA', linewidth=1.5)

 

#x axis
plt.xlabel('GAMEWEEK')
#y axis
plt.ylabel('XG')
#title
plt.legend()
plt.title('NIGER TORNADOES')
plt.savefig('NIGER TORNADOES')

# %%
DoUtd_df
matchwk = DoUtd_df.index + 1
DoUtd_df['GAMEWEEK'] = matchwk

# %%
#plot random no
plt.plot(SpLag_df['GAMEWEEK'],DoUtd_df['XG'],'g',label='XG', linewidth=2)
plt.plot(SpLag_df['GAMEWEEK'], DoUtd_df['XGA'],'r', label='XGA', linewidth=1.5)

 

#x axis
plt.xlabel('GAMEWEEK')
#y axis
plt.ylabel('XG')
#title
plt.legend()
plt.title('DOMA UNITED')
plt.savefig('DOMA UNITED')

# %%
ReSt_df
ReSt_df = ReSt_df.dropna()
ReSt_df
matchwk = ReSt_df.index + 1
ReSt_df['GAMEWEEK'] = matchwk
# Out:
# C:\Users\BeanyAgads\AppData\Local\Temp\ipykernel_61172\2825652978.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ReSt_df['GAMEWEEK'] = matchwk

# %%
#plot random no
plt.plot(ReSt_df['GAMEWEEK'],ReSt_df['XG'],'g',label='XG', linewidth=2)
plt.plot(ReSt_df['GAMEWEEK'], ReSt_df['XGA'],'r', label='XGA', linewidth=1.5)

 

#x axis
plt.xlabel('GAMEWEEK')
#y axis
plt.ylabel('XG')
#title
plt.legend()
plt.title('REMO STARS')
plt.savefig('REMO STARS')

# %%
RiUtd_df
matchwk = RiUtd_df.index + 1
RiUtd_df['GAMEWEEK'] = matchwk

# %%
#plot random no
plt.plot(RiUtd_df['GAMEWEEK'],RiUtd_df['XG'],'g',label='XG', linewidth=2)
plt.plot(RiUtd_df['GAMEWEEK'], RiUtd_df['XGA'],'r', label='XGA', linewidth=1.5)

 

#x axis
plt.xlabel('GAMEWEEK')
#y axis
plt.ylabel('XG')
#title
plt.legend()
plt.title('RIVERS UNITED')
plt.savefig('RIVERS UNITED')

# %%
BdIns_df
matchwk = BdIns_df.index + 1
BdIns_df['GAMEWEEK'] = matchwk

# %%
#plot random no
plt.plot(SpLag_df['GAMEWEEK'],BdIns_df['XG'],'g',label='XG', linewidth=2)
plt.plot(SpLag_df['GAMEWEEK'], BdIns_df['XGA'],'r', label='XGA', linewidth=1.5)

 

#x axis
plt.xlabel('GAMEWEEK')
#y axis
plt.ylabel('XG')
#title
plt.legend()
plt.title('BENDEL INSURANCE')
plt.savefig('BENDEL INSURANCE')

# %%
Enyba_df
matchwk = Enyba_df.index + 1
Enyba_df['GAMEWEEK'] = matchwk

# %%
#plot random no
plt.plot(Enyba_df['GAMEWEEK'],Enyba_df['XG'],'g',label='XG', linewidth=2)
plt.plot(Enyba_df['GAMEWEEK'], Enyba_df['XGA'],'r', label='XGA', linewidth=1.5)

 

#x axis
plt.xlabel('GAMEWEEK')
#y axis
plt.ylabel('XG')
#title
plt.legend()
plt.title('ENYIMBA')
plt.savefig('ENYIMBA')

# %%
LbSt_df
matchwk = LbSt_df.index + 1
LbSt_df['GAMEWEEK'] = matchwk

# %%
#plot random no
plt.plot(LbSt_df['GAMEWEEK'],LbSt_df['XG'],'g',label='XG', linewidth=2)
plt.plot(LbSt_df['GAMEWEEK'], LbSt_df['XGA'],'r', label='XGA', linewidth=1.5)


 

#x axis
plt.xlabel('GAMEWEEK')
#y axis
plt.ylabel('XG')
#title
plt.legend()
plt.title('LOBI STARS')
plt.savefig('LOBI STARS')

# %%
PlatUtd_df
matchwk = PlatUtd_df.index + 1
PlatUtd_df['GAMEWEEK'] = matchwk

# %%
#plot random no
plt.plot(PlatUtd_df['GAMEWEEK'],PlatUtd_df['XG'],'g',label='XG', linewidth=2)
plt.plot(PlatUtd_df['GAMEWEEK'], PlatUtd_df['XGA'],'r', label='XGA', linewidth=1.5)

 

#x axis
plt.xlabel('GAMEWEEK')
#y axis
plt.ylabel('XG')
#title
plt.legend()
plt.title('PLATEAU UNITED')
plt.savefig('PLATEAU UNITED')

# %%
KatUtd_df
matchwk = KatUtd_df.index + 1
KatUtd_df['GAMEWEEK'] = matchwk

# %%
#plot random no
plt.plot(KatUtd_df['GAMEWEEK'],KatUtd_df['XG'],'g',label='XG', linewidth=2)
plt.plot(KatUtd_df['GAMEWEEK'], KatUtd_df['XGA'],'r', label='XGA', linewidth=1.5)

 

#x axis
plt.xlabel('GAMEWEEK')
#y axis
plt.ylabel('XG')
#title
plt.legend()
plt.title('KATSINA UNITED')
plt.savefig('KATSINA UNITED')

# %%
ShooSt_df
matchwk = ShooSt_df.index + 1
ShooSt_df['GAMEWEEK'] = matchwk

# %%
#plot random no
plt.plot(SpLag_df['GAMEWEEK'],ShooSt_df['XG'],'g',label='XG', linewidth=2)
plt.plot(SpLag_df['GAMEWEEK'], ShooSt_df['XGA'],'r', label='XGA', linewidth=1.5)

 

#x axis
plt.xlabel('GAMEWEEK')
#y axis
plt.ylabel('XG')
#title
plt.legend()
plt.title('SHOOTING STARS')
plt.savefig('SHOOTING STARS')

# %%
SunSt_df
matchwk = SunSt_df.index + 1
SunSt_df['GAMEWEEK'] = matchwk

# %%
#plot random no
plt.plot(SpLag_df['GAMEWEEK'],SunSt_df['XG'],'g',label='XG', linewidth=2)
plt.plot(SpLag_df['GAMEWEEK'], SunSt_df['XGA'],'r', label='XGA', linewidth=1.5)

 

#x axis
plt.xlabel('GAMEWEEK')
#y axis
plt.ylabel('XG')
#title
plt.legend()
plt.title('SUNSHINE STARS')
plt.savefig('SUNSHINE STARS')
